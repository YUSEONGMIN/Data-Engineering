# %% [markdown]
# # 데이터 시각화의 개념 및 필요성
#
# ## 데이터 시각화
# - 데이터의 분석 결과를 쉽게 이해하고 판단할 수 있도록 데이터를 시각적으로 표현하여 전달하기 위한 과정을 말한다.
#
# ## 필요성
# - 많은 양의 데이터를 한눈에 파악할 수 있다. 시각적 요소를 활용해 데이터를 요약한다.
# - 데이터 분석에 대한 전문적 지식이 없더라도 누구나 해당 데이터를 인지하고 활용할 수있게한다.
#     - 사람이 감각기관을 통해 획득하는 정보의 80%는 시각에 의한 것이다.
#     - 시각적인 입력은 다른 어떤 방법보다 빠르고 쉽게 사람이 이해할 수 있다.
#     - 시각화 형태, 요소, 위치, 색등을 기반으로 패턴이나 다양한 인사이트(의미있는 정보)를 도출 및 표현할 수 있다.
# - 단순한 데이터 요약, 통계분석 결과보다 정확한 데이터 분석결과를 도출할 수있다.
#     - 데이터의 패턴이나 추세, 데이터간 비교등 표(Table)로 쉽게 인식 할 수 없는 것들을 시각적으로 쉽게 확인할 수 있다.
#
# # 대표적 파이썬 시각화 라이브러리
# - matplotlib
# - seaborn
# - pandas
# - plotly
# - folium

# %% [markdown]
# #  Matplotlib
# - 데이터의 시각화를 위한 파이썬 패키지
# - 2차원 그래프를 위한 패키지이나 확장 API들을 이용해 3D 그래프등 다양한 형식의 시각화를 지원
# - 파이썬 기반의 다른 시각화 패키지의 기본이 된다.
#     - Seaborn, Pandas 등이 Matplotlib를 기반으로 사용한다.
# - https://matplotlib.org

# %% [markdown]
# ## matplotlib 그래프 구성요소
# ![image.png](attachment:image.png)

# %% [markdown]
# - **figure**
#     - 전체 그래프가 위치할 기본 틀
#     - 하나의 figure에 여러개의 그래프를 그릴 수 있다.
#     - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html
# - **axes(subplot)**
#     - figure내에 한개의 그래프를 그리기 위한 공간
#         - figure에 한개 이상의 axes(subplot)로 구성해서 각 axes에 그래프를 그린다.
#     - https://matplotlib.org/stable/api/axes_api.html
# - **axis**
#     - 축 (x축, y축)은 값들을 위치시키는 선을 말한다.
#     - axis label (x, y) : 축의 레이블(설명)
# - **ticks** : 축의 값을 알려주는 눈금
#     - Major tick
#     - Minor tick
# - **title** : 플롯 제목
# - **legend (범례)**
#     - 하나의 axes내에 여러 그래프를 그린 경우 그것에 대한 설명

# %%
# %matplotlib inline
# %matplotlib qt

import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(15,7), facecolor='gray') #facecolor: figure의 배경색
axes1 = fig.add_subplot(1,2,1)
axes2 = fig.add_subplot(1,2,2)

axes1.plot([1,2,3,4,5], [10,20,30,40,50], label='line1')
axes1.plot([1,2,3,4,5], [50,40,30,20,10], label='line2')
axes2.scatter(np.random.randint(100, size=50), np.random.randint(100, 200, size=50), color='r')

fig.suptitle('Example of Plot', size=25, color='blue') #size: 폰트크기, color: 글자색
axes1.set_title("PLOT 1", size=20)
axes2.set_title("Plot 2", size=20)

axes1.set_xlabel("X축", size=15)
axes1.set_ylabel("Y축", size=15)
axes2.set_xlabel("가격1", size=15)
axes2.set_ylabel('가격2', size=15)

axes1.legend()
axes1.grid(True)
plt.show()

# %% [markdown]
# # %matplotlib qt
#
# 위에는 새 창을 띄워서 그래프를 보여주는 코드
#
# # %matplotlib inline
#
# 아래는 새 창을 띄우지 않고 바로 보여주는 코드

# %%
# %matplotlib inline
# %matplotlib qt

import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(15,7), facecolor='gray') #facecolor: figure의 배경색
axes1 = fig.add_subplot(1,2,1)
axes2 = fig.add_subplot(1,2,2)

axes1.plot([1,2,3,4,5], [10,20,30,40,50], label='line1')
axes1.plot([1,2,3,4,5], [50,40,30,20,10], label='line2')
axes2.scatter(np.random.randint(100, size=50), np.random.randint(100, 200, size=50), color='r')

fig.suptitle('Example of Plot', size=25, color='blue') #size: 폰트크기, color: 글자색
axes1.set_title("PLOT 1", size=20)
axes2.set_title("Plot 2", size=20)

axes1.set_xlabel("X축", size=15)
axes1.set_ylabel("Y축", size=15)
axes2.set_xlabel("가격1", size=15)
axes2.set_ylabel('가격2', size=15)

axes1.legend()
axes1.grid(True)
plt.show()

# %% [markdown]
# # 그래프 그리기
# 1. matplotlib.pyplot 모듈을 import
#     - 2차원 그래프(axis가 두개인 그래프)를 그리기위한 함수를 제공하는 모듈
#     - 별칭(alias) 로 plt를 관례적으로 사용한다.
#     - `import matplotlib.pyplot as plt`
#
# 2. 그래프를 그린다.
#
# 3. 그래프에 필요한 설정을 한다.
#
# 4. 화면에 그린다.
#     - 지연 랜더링(Deferred rendering) 메카니즘
#     - 마지막에 `pyplot.show()` 호출 시 그래프를 그린다.
#         <!-- - 주피터 노트북 맨 마지막 코드에 `;`를 붙이는 것으로 대체할 수 있다. -->
#     - 주피터 노트북에서는 생략할 수 있다.

# %% [markdown]
# # 그래프를 그리는 두가지 방식
# - pyplot 모듈의 함수들을 사용한다.
# - Figure와 Axes 객체의 메소드들을 사용한다.

# %% [markdown]
# ## pyplot 모듈을 이용해 그리기
# 1. pyplot 모듈이 그래프 그리는 함수와 Axes(Subplot) 설정 관련 함수를 제공

# %%
# 그래프에 사용할 데이터
x = [1, 2, 3, 4, 5]
y = [10, 5, 30, 30, 50]

# %%
import matplotlib.pyplot as plt

# %%
# 그래프 그리기
plt.plot(x,y)

# %% [markdown]
# plot(가로축, 세로축)
#
# 가로 축은 x = [1,2,3,4,5]
# 세로 축은 y = [10, 5, 30, 30, 50]

# %%
plt.plot(x,y)

# 설정
plt.title("Line plot 예제") # axes 제목
plt.xlabel("X") # 가로 축 이름
plt.ylabel("Y") # 세로 축 이름

# repr의 특징: Text(0, 0.5, 'Y')와 같은 글자들이 출력됨
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.plot(x,y)

# 설정
plt.title("Line plot 예제") # axes 제목
plt.xlabel("X") # 가로 축 이름
plt.ylabel("Y"); # 세로 축 이름

# repr의 특징: Text(0, 0.5, 'Y')이 나옴
# 마지막에 ; 붙이거나 plt.show() 하면 안나옴 (후자 방법 추천)

# %%
plt.plot(x,y)

# 설정
plt.title("Line plot 예제") # axes 제목
plt.xlabel("X") # 가로 축 이름
plt.ylabel("Y") # 세로 축 이름

plt.grid(True) # 격자 무늬 배경
plt.show()

# %% [markdown]
# 2. 하나의 figure에 여러 그래프 그리기
#     - plt.subplot(row,columns,num)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # figure(figsize = (가로 크기, 세로 크기))
#
# # subplot(A행, B열, A*B 갯수 중 위치)
#
# ## subplot(1, 2, 1): 1행 2열 크기 중 (총 2칸) 1번째 위치 (가로 1줄, 세로 2줄 중 첫번째(왼쪽))
#
# ## subplot(2, 2, 2): 2행 2열 크기 중 (총 4칸) 2번째 위치 (가로 2줄, 세로 2줄 중 우측상단)
#
# ## 위치 순서는 위에서부터 왼쪽, 오른쪽 순서로 1, 2, 3, 4...

# %%
# figure의 크기 변경
plt.figure(figsize=(10, 5)) # (가로, 세로) -> 인치

# 위치
plt.subplot(1, 2, 1)
plt.plot(x, y)
plt.title('첫번째 plot')

# 두번째 위치
plt.subplot(2, 2, 2)
plt.plot(y, x)
plt.title('두번째 plot')

plt.subplot(2, 2, 4) # 2행 2열 중 (4등분) 4번째 위치 (우측 하단)
plt.scatter(y, x)
plt.title('세번째 plot')

plt.tight_layout()
plt.plot()
# Out:
# []

# %%
plt.subplot(3,1,1) # 가로 3줄, 세로 1줄 (총 3칸)
plt.plot([1,1])
plt.title('1')

plt.subplot(4,3,3) # 가로 4줄, 세로 3줄 (총 12칸)
plt.plot([3,3])
plt.title('3')

plt.subplot(4,3,5)
plt.plot([5,5])
plt.title('5')

plt.subplot(4,3,9)
plt.plot([9,9])
plt.title('9')

plt.subplot(4,3,12)
plt.plot([12,12])
plt.xlabel("12")
plt.title('12')

plt.plot()

# 그래프 등분을 잘 맞춰줘야 함 안그럼 겹침
# Out:
# []

# %% [markdown]
# ___
# 3. 하나의 axes에 여러 그래프를 그리기.

# %%
plt.plot(x,y)
plt.plot(y,x)

# %% [markdown]
# # **범위 신경 쓰기**
#
# 위 그래프가 이상하게 나오는 이유는
# 첫번째 그래프는 가로 축 범위가 x = [1, 2, 3, 4, 5] 이고
# 두번째 그래프는 가로 축 범위가 y = [10, 5, 30, 30, 50] 임
#
# ___

# %% [markdown]
# ## Figure 와 Axes 객체를 이용해 그리기
#
# - AxesSubplot 객체(Axes를 표현하는 객체)의 메소드들을 이용해 그래프를 그린다.
# - axes 생성 방법
#     - plt.gca(): AxesSubplot
#         - plt로 그래프를 그릴때 대상 axes 객체를 반환한다.
#         - 하나의 figure에 하나의 Axes 만 사용할 경우 사용.
#     - 하나의 figure에 여러개의 Axes들을 사용할 경우
#         - figure.add_subplot() 메소드 이용
#             - figure를 먼저 생성후 axes 들을 추가
#         - pyplot.subplots() 함수를 이용
#             - figure와 axes배열을 동시에 생성

# %% [markdown]
# ### Figure에 하나의 axes 그리기
# - plt.gca() 사용

# %% [markdown]
# # plt.gca()을 이용해서 ax 라는 객체를 만들면 한 화면에 있는 여러 그래프들을 조절해줄 수 있음

# %%
# 그래프 -> Axes에 그린다. => Axes 객체
ax = plt.gca()
print(type(ax))

ax.plot(x,y,label="plot")
ax.set_title("axes 제목")
ax.set_xlabel("X")
ax.set_ylabel("Y")

ax.grid(True)
ax.legend()

plt.show()
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# ### 하나의 Figure에 여러개의 axes 그리기
# 1. <b style='font-size:1.3em'>figure.add_subplot() 메소드 이용</b>
#     - figure객체에 axes를 추가하는 형태
#     - nrows(총행수), ncols(총열수), index(axes위치) 지정

# %% [markdown]
# 순서는 먼저 fig = plt.figure(figsize=(가로크기,세로크기)) 만들기
# 1. 그림을 그릴 큰 틀 생성
#
# 2. fig에 add_subplot 이용해서 그림 그릴 위치 지정 ax1, ax2, ...
#
# 3. ax1, ax2, ...에 plot 등을 붙여서 그림 그려주기

# %%
# figure 객체 조회
fig = plt.figure(figsize=(10,5))
print(type(fig))

# figure에 axes를 추가
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 4)

ax1.plot(x, y, label='line')
ax1.scatter(x,y,color='r', label='scatter')
ax1.legend()
ax1.set_title('첫번째 plot')

ax2.plot(y, x)
ax2.set_title('두번째 plot')

ax3.scatter(y, x)
ax3.set_title('세번째 plot')

plt.tight_layout()
plt.show()
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
# 그림을 넣어주지 않으면 안나옴

plt.subplot(2, 2, 2)
plt.plot(y, x)
plt.title('두번째 plot')

plt.subplot(2, 2, 4)
plt.plot(x, y, label='line')
plt.scatter(x,y,color='r', label='scatter')
plt.legend()
plt.title('첫번째 plot')

plt.scatter(y, x)
plt.title('세번째 plot')

# 그림이 첫번째와 세번째가 겹침
# 위치 정해주고 그림 그려주고, 다음 위치 정해주고 그림 그려주고 순서로

plt.tight_layout()
plt.show()

# %% [markdown]
# # subplot은 만들 때 위치 정해주고 그림 그려주고 다음 위치 정해주고 다음 그림 그려주고..
#
# # gca()를 이용한 ax는 한번에 위치 정해주고 그림 그리기

# %%
fig = plt.figure()
ax = fig.add_subplot(111) # ax=plt.gca()
ax.plot(x,y)
plt.show()

# %% [markdown]
# # subplot(1,2,1) 가로 1줄 세로 2줄 중 1번째 위치 라는 뜻
# # subplot(121) 컴마(,)를 생략할 수 있음

# %% [markdown]
# 2. <b style='font-size:1.3em'>pyplot.subplots()</b>
#     - nrows, ncols 로 axes개수와 위치 지정
#     - 반환: figure와 axes(subplot)들을 담은 **ndarray**

# %% [markdown]
# # subplot과 다르게 subplots는 한번에 위치들을 정해줌
#
# # 특별한 점은 subplots는 figure 부분과 axes 부분을 나눠서 제공함 (그림을 그릴 틀 부분과 틀 안에 들어갈 각 그림들의 축)
# # fig, axes = plt.subplots(2,2, figsize=(가로크기, 세로크기))를 하면
# # 앞에 fig는 plt.figure(figsize=(가로크기, 세로크기))를 한 것처럼 되고
# # 뒤에 axes는 plt.subplot(2,2,1), plt.subplot(2,2,2), plt.subplot(2,2,3), plt.subplot(2,2,4)로 여러개 나옴 <- 배열 형태로 나옴
# # 그래서 axes[0,0],axes[0,1],axes[1,0],axes[1,1] 총 4개를 지정해줄 수 있음

# %%
fig, axes = plt.subplots(2,2, figsize=(10,10)) # 가로 2줄, 세로 2줄이므로 2*2 = 4칸
print(type(fig))
print(type(axes))
print(type(axes[0,0]))

axes[0,0].plot(x,y)
axes[0,1].plot(x,y)

# 0행 0열 (좌측상단) -> subplot(2,2,1)
# 0행 1열 (우측상단) -> subplot(2,2,2)
# 1행 0열 (좌측하단) -> subplot(2,2,3)
# 1행 1열( 우측하단) -> subplot(2,2,4)
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'numpy.ndarray'>
# <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# # 색상과 스타일
#
# ## 색을 지정하는 방법
# - color 또는 c 매개변수를  이용해 지정
# - **색상이름으로 지정.**
#     - 색이름 또는 약자로 지정 가능
#     - 'red', 'r'
#
# | 문자열 | 약자 |
# |-|-|
# | `blue` | `b` |
# | `green` | `g` |
# | `red` | `r` |
# | `cyan` | `c` |
# | `magenta` | `m` |
# | `yellow` | `y` |
# | `black` | `k` |
# | `white` | `w` |
#
#
# - **HTML Color Hex code**
#     - #으로 시작하며 RGB의 성분을 16진수로 표현
#     - #RRGGBB 또는 #RRGGBBAA
#     - #FF0000, #00FF00FA
# - **0 ~ 1 사이 실수로 흰식과 검정색 사이의 회색조를 표시**
#     - 0: 검정, 1: 흰색
# - **color 값 검색**
#     - https://matplotlib.org/examples/color/named_colors.html
#     - https://htmlcolorcodes.com/
#         - picker, chart(코드), name(색이름) 제공사이트
#     - google 에서 `color picker`로 검색

# %%
plt.plot(x,y, color='red') # color 옵션: 선 색깔

# %%
plt.plot(x,y, color='r') # red의 약자 r도 가능

# %%
plt.plot(x,y, color='#00FF00FA') # 색상코드도 가능

# %%
plt.plot(x,y, color='0.8') # 투명도 조절 가능 1에 가까워질수록 투명해짐

# %% [markdown]
# ## Style 설정
# - Style: 그래프의 여러 시각효과들을 미리 설정해 놓은 것
# - matplotlib는 다양한 스타일들을 미리 정의해 놓고 있다.
#     - [스타일목록](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)
#     - `plt.style.use()` 함수 이용해 지정
#     - `plt.style.available`
#         - 사용할 수 있는 스타일 이름 조회

# %%
plt.style.use('ggplot')
plt.plot(x,y)
# ggplot 스타일

# %%
plt.style.use('classic')
plt.plot(x,y)
# 스타일 목록 사이트에 여러 스타일들이 있음

# %%
plt.plot(x,y)

# %% [markdown]
# # 스타일을 한번 지정해주면 계속 적용됨
